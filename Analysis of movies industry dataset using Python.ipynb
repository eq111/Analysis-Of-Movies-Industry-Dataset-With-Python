# %%
#importing Libraries.
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# %%
#reading Data.
mv = pd.read_csv('movies.csv')
mv
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
#checking every column's data type.
mv.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#checking for missing data.
for col in mv.columns:
    per_missing = np.mean(mv[col].isnull())
    print('{} - {}%'.format(col, per_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
#Replace missing data.
mv_c = mv.copy()
mv_c['rating'].fillna("-", inplace=True)
mv_c['released'].fillna("-", inplace=True)
mv_c['score'].fillna(0, inplace=True)
mv_c['votes'].fillna(0, inplace=True)
mv_c['writer'].fillna("-", inplace=True)
mv_c['star'].fillna("-", inplace=True)
mv_c['country'].fillna("-", inplace=True)
mv_c['budget'].fillna(0, inplace=True)
mv_c['gross'].fillna(0, inplace=True)
mv_c['company'].fillna("-", inplace=True)
mv_c['runtime'].fillna(0, inplace=True)
mv_c
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life      -      Drama  2020
# 7664                                     Dream Round      -     Comedy  2020
# 7665                                   Saving Mbango      -      Drama  2020
# 7666                                    It's Just Us      -      Drama  2020
# 7667                                       Tee em el      -     Horror  2020
#
# ...

# %%
mv = mv_c
mv
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life      -      Drama  2020
# 7664                                     Dream Round      -     Comedy  2020
# 7665                                   Saving Mbango      -      Drama  2020
# 7666                                    It's Just Us      -      Drama  2020
# 7667                                       Tee em el      -     Horror  2020
#
# ...

# %%
#checking for missing data again.
for col in mv.columns:
    per_missing = np.mean(mv[col].isnull())
    print('{} - {}%'.format(col, per_missing))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
#Getting rid of unnecessary formats.
mv['budget'] = mv['budget'].astype('int64')
mv['gross'] = mv['gross'].astype('int64')
mv['votes'] = mv['votes'].astype('int64')
mv['runtime'] = mv['runtime'].astype('int64')
mv.head(50)
# Out:
#                                               name rating      genre  year  \
# 0                                      The Shining      R      Drama  1980
# 1                                  The Blue Lagoon      R  Adventure  1980
# 2   Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                        Airplane!     PG     Comedy  1980
# 4                                       Caddyshack      R     Comedy  1980
# 5                                  Friday the 13th      R     Horror  1980
# 6                               The Blues Brothers      R     Action  1980
# 7                                      Raging Bull      R  Biography  1980
# 8                                      Superman II     PG     Action  1980
# 9                                  The Long Riders      R  Biography  1980
# 10                           Any Which Way You Can     PG     Action  1980
# ...

# %%
#checking for duplicates.
mv_c.drop_duplicates()
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life      -      Drama  2020
# 7664                                     Dream Round      -     Comedy  2020
# 7665                                   Saving Mbango      -      Drama  2020
# 7666                                    It's Just Us      -      Drama  2020
# 7667                                       Tee em el      -     Horror  2020
#
# ...

# %%
#common analysis
mv.describe()
# Out:
#               year        score         votes        budget         gross  \
# count  7668.000000  7668.000000  7.668000e+03  7.668000e+03  7.668000e+03
# mean   2000.405451     6.387911  8.807403e+04  2.551350e+07  7.656567e+07
# std      11.153508     0.976862  1.633011e+05  3.858954e+07  1.641217e+08
# min    1980.000000     0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1991.000000     5.800000  9.100000e+03  0.000000e+00  3.860582e+06
# 50%    2000.000000     6.500000  3.300000e+04  1.200000e+07  1.895543e+07
# 75%    2010.000000     7.100000  9.300000e+04  3.200000e+07  7.262022e+07
# max    2020.000000     9.300000  2.400000e+06  3.560000e+08  2.847246e+09
#
#            runtime
# count  7668.000000
# mean    107.205660
# std      18.737179
# min       0.000000
# 25%      95.000000
# 50%     104.000000
# 75%     116.000000
# max     366.000000

# %%
#From this we can see that budget and gross have the highest correlation then there is votes and gross.
correlationMatrix = mv.corr()
correlationMatrix
# Out:
# C:\Users\Lenonvo\AppData\Local\Temp\ipykernel_12404\2317731703.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlationMatrix = mv.corr()
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.092616  0.222427  0.309212  0.261900  0.116358
# score    0.092616  1.000000  0.407101  0.056863  0.186012  0.394564
# votes    0.222427  0.407101  1.000000  0.486931  0.632870  0.306984
# budget   0.309212  0.056863  0.486931  1.000000  0.750157  0.268372
# gross    0.261900  0.186012  0.632870  0.750157  1.000000  0.244339
# runtime  0.116358  0.394564  0.306984  0.268372  0.244339  1.000000

# %%
#Heatmap to better show the correltions.
correlationMatrix = mv.corr()

sns.heatmap(correlationMatrix, annot=True)

plt.show()
# Out:
# C:\Users\Lenonvo\AppData\Local\Temp\ipykernel_12404\3255672264.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlationMatrix = mv.corr()

# %%
#looking for highest and lowest 5 by gross.
mv.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name rating    genre  year  \
# 5445                                      Avatar  PG-13   Action  2009
# 7445                           Avengers: Endgame  PG-13   Action  2019
# 3045                                     Titanic  PG-13    Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13   Action  2015
# 7244                      Avengers: Infinity War  PG-13   Action  2018
# ...                                          ...    ...      ...   ...
# 1617                             Mortal Passions      R    Crime  1989
# 1614                              Edge of Sanity      R   Horror  1989
# 1606                                   I, Madman      R  Fantasy  1989
# 1601                        My Twentieth Century      -   Comedy  1989
# 7667                                   Tee em el      -   Horror  2020
#
#                                released  score    votes        director  \
# ...

# %%
#Number of produced films of each genre.
mv[['genre', 'name']].pivot_table(index=['genre'], aggfunc='count').T
# Out:
# genre  Action  Adventure  Animation  Biography  Comedy  Crime  Drama  Family  \
# name     1705        427        338        443    2245    551   1518      11
#
# genre  Fantasy  History  Horror  Music  Musical  Mystery  Romance  Sci-Fi  \
# name        44        1     322      1        2       20       10      10
#
# genre  Sport  Thriller  Western
# name       1        16        3

# %%
#Bar chart shows that comedy is the highest produced genre then action then drama and so on..
mv[['genre', 'name']].pivot_table(index=['genre'], aggfunc='count').plot(kind='bar', ylabel='The Number Of Movies', 
                                                                         title='The number of movies for each genre',
                                                                        color='blue')
plt.show()

# %%
#Number of gross by each genre.
mv[['genre', 'gross']].pivot_table(index=['genre'], aggfunc='sum').T
# Out:
# genre        Action    Adventure    Animation    Biography       Comedy  \
# gross  243435855754  45916596693  80142045796  20729581801  97175468462
#
# genre        Crime        Drama      Family     Fantasy  History       Horror  \
# gross  21355448322  57150648537  2157897417  1664501135        0  14543329602
#
# genre   Music  Musical     Mystery    Romance     Sci-Fi    Sport   Thriller  \
# gross  110014  5190692  2023670554  188394999  260489866  1067629  323223113
#
# genre   Western
# gross  32025886

# %%
#As we can see, despite the fact that comedy  is the highest produced, it is the second in gross for the action genre 
mv[['genre', 'gross']].pivot_table(index=['genre'], aggfunc='sum').plot(kind='bar', ylabel='Total gross of each genre', 
                                                                         title='The number of gross prodused by each genre',
                                                                         color='green')

plt.show()

# %%
#Budget to gross for each genre.
mv[['genre', 'gross','budget']].pivot_table(index=['genre'], aggfunc='sum').T
# Out:
# genre         Action    Adventure    Animation    Biography       Comedy  \
# budget   82886723068  15038060000  21144070000   7973379768  34137781215
# gross   243435855754  45916596693  80142045796  20729581801  97175468462
#
# genre         Crime        Drama      Family     Fantasy  History  \
# budget   9057244080  20164855737   204500000   709200000   323562
# gross   21355448322  57150648537  2157897417  1664501135        0
#
# genre        Horror   Music  Musical     Mystery    Romance     Sci-Fi  \
# budget   3385842000       0        0   541900001  120200000  157870000
# gross   14543329602  110014  5190692  2023670554  188394999  260489866
#
# genre     Sport   Thriller   Western
# budget        0   94600000  21000000
# gross   1067629  323223113  32025886

# %%
#Budget to gross chart.
mv[['genre','gross', 'budget']].pivot_table(index=['genre'], aggfunc='sum').plot(kind='bar', ylabel='The Number Of Movies', 
                                                                         title='The number of movies for each genre',
                                                                        )

plt.show()

# %%
#Budget to gross map, we can see that all films scattered around the diagonal from high right to low left(spend - return)
sns.regplot(x='budget', y='gross', data=mv, scatter_kws={"color":"green"}, line_kws={"color":"blue"})

plt.title('Budget to gross scatter')

plt.show()

# %%
#Total Movies' industry for each year, with highest at 2019 and lowest at 1980
yearGross = mv[['year', 'gross']].pivot_table(index='year', aggfunc='sum')
yearGross.sort_values(by='gross', inplace=True, ascending=False)
yearGross
# Out:
#             gross
# year
# 2019  30339653041
# 2016  28938844792
# 2017  28485248415
# 2018  28085289459
# 2015  26746011088
# 2014  26491482563
# 2013  25995848674
# 2012  25476190195
# 2011  24837686836
# 2009  23338680609
# 2010  23106595534
# 2008  21702162009
# 2007  20383671799
# 2004  18721747812
# 2006  18654070363
# 2005  17866609897
# 2003  17661932024
# 2002  17003436520
# 2001  15617625148
# 1999  13509638121
# 2000  13454129869
# 1997  13112275767
# 1998  11176023159
# 1996   9819527991
# 1995   9448305484
# 1994   9062925753
# 1993   8053959337
# 1992   7334167717
# 1990   6804235860
# 1991   6254770668
# 1989   6087250779
# 1988   4840385631
# 1987   4033434255
# 1985   3691509283
# 1986   3647511836
# 1984   3533092196
# 1982   3187580517
# 2020   2848298792
# 1983   2750004626
# 1981   2520064889
# 1980   2483666964

# %%
yearGross.plot(kind='bar', color='blue', ylabel='gross', title='Gross of each year')

plt.show()

# %%
mvNum = mv.copy()

for colName in mvNum.columns:
    if (mvNum[colName].dtype == 'object'):
        mvNum[colName] = mvNum[colName].astype('category')
        mvNum[colName] = mvNum[colName].cat.codes
        
mvNum
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 0     6587       7      6  1980      1706    8.4   927000      2589    4015
# 1     5573       7      1  1980      1493    5.8    65000      2269    1633
# 2     5142       5      0  1980      1772    8.7  1200000      1111    2568
# 3      286       5      4  1980      1493    7.7   221000      1301    2001
# 4     1027       7      4  1980      1544    7.3   108000      1054     522
# ...    ...     ...    ...   ...       ...    ...      ...       ...     ...
# 7663  3705       0      6  2020      2965    3.1       18      1500    2290
# 7664  1678       0      4  2020      1108    4.7       36       774    2615
# 7665  4717       0      6  2020       194    5.7       29      2061    2684
# 7666  2843       0      6  2020      2818    0.0        0      1184    1825
# 7667  5394       0     10  2020       392    5.7        7      2165    3345
#
# ...

# %%
mv
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life      -      Drama  2020
# 7664                                     Dream Round      -     Comedy  2020
# 7665                                   Saving Mbango      -      Drama  2020
# 7666                                    It's Just Us      -      Drama  2020
# 7667                                       Tee em el      -     Horror  2020
#
# ...

# %%
mvNumMat = mvNum.corr()

mvNumMat
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.008069  0.016355  0.011453 -0.011311  0.016377
# rating   -0.008069  1.000000  0.072423  0.008779  0.016613  0.006192
# genre     0.016355  0.072423  1.000000 -0.081261  0.029822  0.027384
# year      0.011453  0.008779 -0.081261  1.000000 -0.000695  0.092616
# released -0.011311  0.016613  0.029822 -0.000695  1.000000  0.039814
# score     0.016377  0.006192  0.027384  0.092616  0.039814  1.000000
# votes     0.013038  0.033743 -0.145296  0.222427  0.015878  0.407101
# director  0.009079  0.019483 -0.015258 -0.020795 -0.001478  0.010568
# writer    0.009081 -0.005920  0.006567 -0.008655 -0.002404  0.022098
# star      0.006472  0.013404 -0.005477 -0.027242  0.015776 -0.000026
# country  -0.010737  0.081244 -0.037615 -0.070938 -0.020427 -0.133346
# budget    0.020548 -0.081939 -0.334021  0.309212  0.009145  0.056863
# gross     0.006989 -0.095450 -0.234297  0.261900  0.000519  0.186012
# ...

# %%
#Correlations between all movies' dataset elements. The more investment you put in the more return you will get out.
sns.heatmap(mvNumMat, annot=True)

plt.show()

# %%
corrPeirs = mvNumMat.unstack()

# %%
sortedPeirs = corrPeirs.sort_values()

# %%
#highest correlations.
highCorrelation = sortedPeirs[(sortedPeirs)>0.5]

highCorrelation.head(4)
# Out:
# votes   gross     0.632870
# gross   votes     0.632870
#         budget    0.750157
# budget  gross     0.750157
# dtype: float64

# %%
# each company share of the industry
companyShare = mv[['company', 'gross']].pivot_table(index='company', aggfunc='sum')
companyShare.sort_values(by=['gross'], inplace=True, ascending=False)
companyShare
# Out:
#                                     gross
# company
# Warner Bros.                  56491421806
# Universal Pictures            52514188890
# Columbia Pictures             43008941346
# Paramount Pictures            40493607415
# Twentieth Century Fox         40257053857
# ...                                   ...
# Georgian-Film                           0
# The Jerry Gross Organization            0
# Abominable Pictures                     0
# The Mount Company (II)                  0
# Les Films de la Tour                    0
#
# [2386 rows x 1 columns]

# %%
#The biggist 10 companies in the market which hold more tha a Half of it's gross.
companyShare.head(10)
# Out:
#                              gross
# company
# Warner Bros.           56491421806
# Universal Pictures     52514188890
# Columbia Pictures      43008941346
# Paramount Pictures     40493607415
# Twentieth Century Fox  40257053857
# Walt Disney Pictures   36327887792
# New Line Cinema        19883797684
# Marvel Studios         15065592411
# DreamWorks Animation   11873612858
# Touchstone Pictures    11795832638

# %%
companyShare.tail(2376).sum()
# Out:
# gross    259393609575
# dtype: int64

# %%
theWholeMarket = companyShare.head(10).T
theWholeMarket['others'] = 259393609575

# %%
#The biggest 10 have more than a half of the industry, which include 2386 companies
theWholeMarket.T.plot(kind='pie', y='gross')

plt.title('Biggest 10 companies share of the movie industry')

plt.show()
